# %%
import pandas as pd
import sqlite3

# %%
db = sqlite3.connect('C:/Users/HP/DS , ML/SQLite/IMDB.sqlite')
cur = db.cursor()

# %%
genre_df = pd.read_sql_query("Select * from genre", db)
# Out:
# dtype('O')

# %%
earning = pd.read_sql_query("Select * from earning", db)
pd.set_option('precision' , 15)
earning['total_earning'] = earning['Domestic'] + earning['Worldwide']
index = earning.total_earning.idxmax()
movie_id = earning['Movie_id'].iloc[index]

loc  = IMDB.Rating.loc[IMDB['Movie_id'] == movie_id]
print(loc.values[0])
earning
# Out:
# 8.1
#     Movie_id   Domestic     Worldwide  total_earning
# 0      36809   56671993   187733202.0    244405195.0
# 1      30114   18335230    60738797.0     79074027.0
# 2      37367   35014192    39187783.0     74201975.0
# 3      49473   15322921    87100449.0    102423370.0
# 4      14867    6739492    19839492.0     26578984.0
# 5      33832  136025503   232325503.0    368351006.0
# 6      31722  100546139   203388186.0    303934325.0
# 7      25398    8114627    11176469.0     19291096.0
# 8      10099  222527828   657818612.0    880346440.0
# 9      25281   42340598   103215094.0    145555692.0
# 10     43358  106954678   329398046.0    436352724.0
# 11     36798   25352281    44495281.0     69847562.0
# 12     10617   72313754   165478348.0    237792102.0
# 13     49590  408084349  1153304495.0   1561388844.0
# 14     12560  259766572   714264267.0    974030839.0
# 15     31370    5879736     5879736.0     11759472.0
# 16     48626  107100855   218791811.0    325892666.0
# ...

# %%
IMDB = pd.read_sql_query("Select * from IMDB", db)
earning.Worldwide.dtype
def f(val):
    return int(val)
IMDB['Budget'].replace('','0',inplace=True) 
IMDB['Budget']=IMDB['Budget'].apply(f)


#IMDB = IMDB[IMDB['Budget'] != 0]
IMDB = IMDB[IMDB['Budget'] == IMDB['Budget'].min()]
IMDB
# Out:
#    Movie_id                   Title  Rating  TotalVotes MetaCritic  Budget  \
# 22    43526       Detachment (2011)     7.7       62352                  0
# 44    29611  I, Daniel Blake (2016)     7.9       28350         78       0
# 65    12744            Pride (2014)     7.8       40577         79       0
#
#    Runtime CVotes10 CVotes09 CVotes08  ... Votes3044 Votes3044M Votes3044F  \
# 22             8602    11683    20411  ...       7.6        7.6        7.7
# 44             3576     5803     9651  ...       7.8        7.8        8.1
# 65             6231     7731    13286  ...       7.6        7.5        7.9
#
#    Votes45A Votes45AM Votes45AF VotesIMDB Votes1000 VotesUS VotesnUS
# 22      7.5       7.5       7.7       6.7       6.5     7.5      7.7
# 44      8.0       8.0       8.2       9.1       6.9     7.6      7.9
# 65      7.9       7.8       8.2       8.2       6.7     7.7      7.7
#
# [3 rows x 52 columns]

# %%
genre_df.genre.isnull().sum()
genre_mod_df = genre_df[genre_df['genre'] != '']
genre_mod_df.to_sql("genre_mod", db , if_exists = "replace")
cur.execute('select genre , count(*) from genre_mod group by genre')
for row in cur:
    l = [row[0] , row[1]]
    print(l[0] , l[1])
# Out:
# Action 33
# Adventure 43
# Animation 13
# Biography 21
# Comedy 31
# Crime 11
# Drama 77
# Family 3
# Fantasy 7
# History 6
# Horror 2
# Music 3
# Musical 1
# Mystery 7
# Romance 13
# Sci-Fi 18
# Sport 3
# Thriller 14
# War 2
# Western 2

# %%
df = pd.merge(IMDB,earning , on = 'Movie_id')
def fun(t):
    return str(t)
def fun2(v):
    val = v.split('(')[1]
    return val
    
df['Title'] = df['Title'].apply(fun)
df['year'] = df.Title.apply(fun2)
def fun3(v):
    val = v.split(')')[0].strip()
    return (val)
df.year.apply(fun3)
df
#df.year = pd.to_numeric(df.year)
# Out:
#     Movie_id                                              Title  \
# 0      36809                            12 Years a Slave (2013)
# 1      30114                                   127 Hours (2010)
# 2      37367                                       50/50 (2011)
# 3      49473                                  About Time (2013)
# 4      14867                                       Amour (2012)
# 5      33832                                        Argo (2012)
# 6      31722                                     Arrival (2016)
# 7      25398                             Before Midnight (2013)
# 8      10099                                  Big Hero 6 (2014)
# 9      25281  Birdman or (The Unexpected Virtue of Ignorance...
# 10     43358                                  Black Swan (2010)
# 11     36798                                     Boyhood (2014)
# 12     10617                             Bridge of Spies (2015)
# 13     49590                  Captain America: Civil War (2016)
# ...
